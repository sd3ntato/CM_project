# %%
# various imports

import numpy as np
import matplotlib.pyplot as plt
from numpy import tanh
from IPython.display import clear_output
from sklearn import preprocessing
from sklearn.utils import shuffle

# %%
# i import my implementation of multi-layer perceptron

from MLP import *

# %%
# i define a dataset to test my nets on 1-dimensional regression task. the dataset is composed of a number of patterns 
# ( x, f_target(x)+some_noise ),
# generated as follows:

# definition of the function to do regression on
f_target = lambda x: x**3 - x**2

#generate data
tx = np.sort( ( 2*np.random.rand(300)-1 )*2 ) # random sorted input
ty = np.array( [ f_target(x) + (2*np.random.rand()-1) for x in tx ] ) # desired output, plus some noise

# rescale input
tx = (tx-np.min(tx))/(np.max(tx)-np.min(tx))

# give data the proper shape
tx = tx.reshape(-1,1)
ty = ty.reshape(-1,1)
data = np.hstack((tx,ty))

# %%
# to test training and performance of the net, i generate one and then i see how it goes before training, then train it, and after 
# i can see how it goes after training:

# define a multi-layer-perceptron, and run it on the test samples even if is not trained yet, just to show that the net works 
# but spits random outputs
n = MLP(  Nh=[5,5,5], Nu=1, Ny=1, f='tanh', f_out='ide', w_scale=2)
outs = n.supply_sequence(tx).reshape(-1) 

# plot the target function
plt.plot(tx,ty,label='target fuction')

#plot the output of the untrained net, then print Mean Sqaured Error (MSE)
plt.plot(tx,outs,label='network outputs')
plt.legend()
print( MSE(outs,ty))
# Out:
# 14.118232957700615

# %%
# now i train my net. In this case i use classical momentum with no regularization. after training i plot some convergence-curves 
# using data i collected during training

# train the net
g,e = n.momentum_train(tx, ty,5e-02,0,max_epochs=100)

# plot learning curves
plt.plot(g)
plt.plot(e)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-680913d2d874> in <module>
#       3
#       4 # train the net
# ----> 5 g,e = n.momentum_train(tx, ty,5e-02,0,max_epochs=100)
#       6
#       7 # plot learning curves
#
# ~/Desktop/CM_project/MLP.py in momentum_train(self, train_x, train_y, mu, epsilon, tresh, max_epochs)
#     233
#     234       # compute step-size using Armijo-Wolfe
# --> 235       alpha = armijo_wolfe(self, 1, d, train_x, train_y, epsilon, 0.01, 0.9, 0.7)
#     236
#     237       #compute velocity v_{t+1}
#
# ~/Desktop/CM_project/utils.py in armijo_wolfe(n, alpha, d, train_x, train_y, epsilon, m1, m2, tau)
#      79   while not ( phi_alpha < phi_zero + m1 * alpha * phi_prime_zero ) and n_iter<10:
#      80     alpha *= tau # decrease tau
# ---> 81     phi_alpha = phi(alpha, n, d, train_x, train_y, epsilon)
#      82     n_iter+=1
#      83
#
# ~/Desktop/CM_project/utils.py in phi(alpha, n, d, train_x, train_y, epsilon)
#      61
#      62   # compute loss of the modified network, a.k.a phi(alpha)
# ---> 63   phi_alpha = n.test_loss(train_x,train_y, epsilon)
#      64
#      65   # reset weights
#
# ~/Desktop/CM_project/MLP.py in test_loss(self, X, Y, epsilon)
#     282
#     283   def test_loss(self, X, Y, epsilon):
# --> 284     outs = self.supply_sequence(X)
#     285     return self.l(outs, Y.reshape(outs.shape)) + epsilon * self.o(self.w)
#     286
#
# ~/Desktop/CM_project/MLP.py in supply_sequence(self, U)
#     275     # calculate sequence of outputs of the network when provided when given sequence of inputs
#     276     sup = self.supply
# --> 277     return np.array(list( map( lambda u : sup(u) , U ) ))
#     278
#     279   def test_error(self, X, Y):
#
# ~/Desktop/CM_project/MLP.py in <lambda>(u)
#     275     # calculate sequence of outputs of the network when provided when given sequence of inputs
#     276     sup = self.supply
# --> 277     return np.array(list( map( lambda u : sup(u) , U ) ))
#     278
#     279   def test_error(self, X, Y):
#
# ~/Desktop/CM_project/MLP.py in supply(self, u)
#     263     a[0] = u
#     264     for m in range(self.Nl+1):
# --> 265       a[m+1] = self.f[m+1](  self.w[m] @ np.vstack(( a[m], 1)) )
#     266     return np.copy(a[self.Nl+1])
#     267
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/shape_base.py in vstack(tup)
#     221
#     222
# --> 223 @array_function_dispatch(_vhstack_dispatcher)
#     224 def vstack(tup):
#     225     """
#
# KeyboardInterrupt:

# %%
# now that i trained my net, i can see how it performs (after training) on the target function (training set). Hopefully, one can
# see that the net has fit the function

# compute output of the net and reshape them in order to plot them
outs = n.supply_sequence(tx)
outs = outs.reshape(ty.shape)

# plot the target function and otuput of the trained network
plt.plot(tx,ty,label='target function')
plt.plot(tx,outs.reshape(-1),label='network outputs')
plt.legend()

print( MSE(outs,ty))
# Out:
# 1.1323638575649746

# %%
from utils import proximal_bundle_method

w, g, e = proximal_bundle_method(n, tx, ty, mu=10, reg_param=0)
plt.plot(g)
plt.plot(e)
if w is not None:
  n.w = w
# Out:
# optimal
# 0.0009411766630445874

# %%
# now that i trained my net, i can see how it performs (after training) on the target function (training set). Hopefully, one can
# see that /the net has fit the function

# compute output of the net and reshape them in order to plot them
outs = n.supply_sequence(tx)
outs = outs.reshape(ty.shape)

# plot the target function and otuput of the trained network
plt.plot(tx,ty,label='target function')
plt.plot(tx,outs.reshape(-1),label='network outputs')
plt.legend()

print( MSE(outs,ty))

# %%
n.w
# Out:
# array([array([[-1.56855468, -1.1171786 ],
#        [ 6.92311377, -7.31156198],
#        [ 9.56255522,  1.48479231],
#        [ 0.22146556,  2.09350683],
#        [-1.34353892, -0.35093005],
#        [-9.50985717, -0.67509758],
#        [ 3.19050532, -4.16319171],
#        [ 1.27545834, -2.79141232],
#        [ 5.75477598, -0.57358409],
#        [ 2.25165225, -4.0141567 ]]),
#        array([[ 0.62287307,  4.99051946,  5.05382786, -0.9619206 ,  0.75786666,
#         -5.25915375,  3.99696186,  2.57816894,  6.25763835,  1.34099146,
#         -1.75404698]])], dtype=object)
